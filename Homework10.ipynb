# %% [markdown]
# # Homework10
#
# Exercises with text processing and NLP modeling
#
# ## Goals
#
# - Understand similarities and differences between the processes of working with text, images and tabular data
# - Practice with different methods of encoding and modeling text data
# - See different methods for extracting information or patterns from text datasets

# %% [markdown]
# ### Setup
#
# Run the following 2 cells to import all necessary libraries and helpers for this homework.

# %%
# !wget -q https://github.com/PSAM-5020-2025S-A/5020-utils/raw/main/src/data_utils.py
# !wget -q https://github.com/PSAM-5020-2025S-A/5020-utils/raw/main/src/text_utils.py

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from data_utils import display_silhouette_plots, object_from_json_url
from text_utils import get_top_words

# %% [markdown]
# You can tell it's gonna be a good homework from the number of imports.
# # 🙃

# %% [markdown]
# ## Have protein, need seasoning
#
# Let's create a model to help us season our foods. In the end, what we want is a model that receives a short list of ingredients and returns a list of seasonings or complementary ingredients for our original ingredients list.
#
# In order to do that we need a dataset of recipes. We'll load that into a text dataset where each recipe is a document and the ingredients are our document *tokens*.
#
# Let's take a look at the recipe dataset and become familiar with the data and how it's organized.
#
# We'll load our recipes and do a bit of exploratory data analysis to look for patterns first to see if this kind of modeling makes any sense.
#
# ### Load Data
#
# Here's our dataset. Let's load it into an object for inspection:

# %%
DATAPATH = "https://raw.githubusercontent.com/PSAM-5020-2025S-A/5020-utils/refs/heads/main/datasets/text/recipes"
recipes_obj = object_from_json_url(f"{DATAPATH}/recipes_min16.json")

# %% [markdown]
# ### Look at Data
#
# How's the data organized?
#
# How many recipes do we have?
#
# Do all recipes have the same number of ingredients?
#
# Anything else stand out about the data?

# %%
# TODO: Look at Data here
print(recipes_obj[0])

# TODO: How many recipes
print("num recipes:", len(recipes_obj))

# TODO: How many ingredients do the shortest and longest recipes have?
ingredients_lists = [len(entry['ingredients']) for entry in recipes_obj]
print("least ingredients:", min(ingredients_lists))
print("most ingredients:", max(ingredients_lists))
# Out:
# {'id': 18009, 'ingredients': ['raisins', 'baking powder', 'egg', 'sugar', 'milk', 'flour']}
# num recipes: 5015
# least ingredients: 5
# most ingredients: 27

# %% [markdown]
# ### Create Input Features
#
# Our dataset doesn't really have to be a `DataFrame` here. It can, but it doesn't have to be.
#
# Each recipe right now is described as a list of ingredients, but what we really want is a list of *sentences*, where each *sentence* is a Python `string` with all of the ingredients for a given recipe.
#
# Instead of:<br>```["salt", "baking soda", "water", "mushroom"]```,
#
# we want:<br>```"salt baking soda water mushroom"```
#
# The `join()` function might help.
#
# Another thing to consider is wether we want to do anything special about multi-word ingredients, like *baking soda*.
#
# Do we want to let our vectorizer (spoiler) split that into two tokens, or do we want to guarantee that *baking* and *soda* always stay together?

# %%
# TODO: turn list of objects into list of strings
for recipe in recipes_obj:
    recipe['ingredients'] = " ".join(recipe['ingredients'] )
print(recipes_obj[0])
# Out:
# {'id': 18009, 'ingredients': 'raisins baking powder egg sugar milk flour'}

# %% [markdown]
# ### Encode Data
#
# The fun part.
#
# Let's vectorize our list of ingredient strings into a sparse document matrix using `CountVectorizer` or `TfidfVectorizer`.
#
# The resulting matrix will have one row for each recipe, and the columns will encode the ingredients.

# %%
# TODO: Vectorize ingredients from our recipe list
cv = CountVectorizer(stop_words = 'english')
ingredients = [r['ingredients'] for r in recipes_obj]
ingredients_vector =cv.fit_transform(ingredients)

# TODO: How many words are in our vocabulary?
vocab = cv.get_feature_names_out()
print(len(vocab))
print(vocab[:10])
# Out:
# 460
# ['adobo' 'agave' 'allspice' 'almond' 'amchur' 'american' 'ancho' 'anchovy'
#  'andouille' 'angel']

# %% [markdown]
# ### Cluster Data
#
# Now that we have our recipes/documents vectorized we can study them a little bit, and look for patterns.
#
# What happens if we cluster our recipes ? What do the cluster centers represent ?
#
# When might this be useful ?

# %%
# TODO: cluster recipes
km_model = KMeans()
clusters = km_model.fit_predict(ingredients_vector)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 7 stored elements and shape (1, 460)>

# %% [markdown]
# ### Cluster Centers
#
# Use the `get_top_words()` function to decode the `cluster_centers` back into ingredients.

# %%
# TODO: Look at cluster centers
get_top_words( km_model.cluster_centers_,vocab)
# Out:
# ([array(['onion', 'salt', 'garlic', 'oil', 'cilantro', 'cumin', 'chili',
#          'pepper', 'tomatoes', 'lime', 'juice', 'ginger', 'black',
#          'coriander', 'vegetable', 'olive', 'rice', 'water', 'masala',
#          'seeds', 'tortilla', 'chicken', 'seed', 'powder', 'turmeric',
#          'yogurt', 'lemon', 'chile', 'cinnamon', 'curry', 'coconut',
#          'broth', 'tumeric', 'red', 'cream', 'sugar', 'avocado', 'cheese',
#          'milk', 'potatoes', 'corn', 'oregano', 'cayenne', 'mustard',
#          'tomato', 'bean', 'butter', 'redpepper', 'cardamom', 'paprika',
#          'bay', 'sour', 'paste', 'beans', 'sauce', 'canola', 'cooking',
#          'vinegar', 'peas', 'carrots', 'egg', 'clove', 'greenpepper',
#          'green', 'stock', 'flour', 'shrimp', 'chickpeas', 'wedges',
#          'spray', 'mint', 'serrano', 'cheddar', 'salsa', 'sticks', 'orange',
#          'pork', 'beef', 'lettuce', 'lentils', 'tomatillos', 'spinach',
#          'cabbage', 'adobo', 'cauliflower', 'zucchini', 'ghee', 'chiles',
#          'fennel', 'cloves', 'heavy', 'jack', 'pods', 'honey', 'kernels',
#          'fenugreek', 'paneer', 'pinto', 'chipotles', 'peanut', 'chipotle',
#          'monterey', 'shoulder', 'ancho', 'celery', 'seasoning', 'sprigs',
#          'raisins', 'chuck', 'parsley', 'turkey', 'olives', 'lamb', 'wine',
#          'shallots', 'cucumber', 'allspice', 'breadcrumbs', 'fish',
#          'kidney', 'scallions', 'eggplant', 'brown', 'squash', 'nuts',
#          'purée', 'cashew', 'poblano', 'almond', 'beer', 'white',
#          'couscous', 'nutmeg', 'kernel', 'lean', 'hot', 'mayonaise',
#          'mushrooms', 'saffron', 'amchur', 'basil', 'mexican', 'kasuri',
#          'sesame', 'cotija', 'enchilada', 'bread', 'ribs', 'methi', 'meat',
#          'liver', 'half', 'baking', 'radishes', 'bell', 'cocoa', 'flank',
#          'stems', 'garbanzo', 'chilees', 'steak', 'anise', 'butternut',
#          'sunflower', 'vegetables', 'tilapia', 'tofu', 'feta', 'harina',
#          'salad', 'starch', 'masa', 'golden', 'mushroom', 'mango', 'wheat',
#          'quinoa', 'apples', 'boiling', 'gingerroot', 'asafoetida',
#          'beansprouts', 'wedge', 'cashews', 'pineapple', 'verde', 'thyme',
#          'bulb', 'tabasco', 'fraîche', 'spices', 'crème', 'okra',
#          'guajillo', 'sausage', 'yellow', 'yellowpepper', 'toasted',
#          'tequila', 'bacon', 'zest', 'whipping', 'wrappers', 'guacamole',
#          'lard', 'star', 'fat', 'double', 'butt', 'cod', 'cornmeal',
#          'dressing', 'ketchup', 'husks', 'rind', 'soy', 'peacheses',
#          'tenderloin', 'threads', 'pinenuts', 'bouillon', 'cold', 'tea',
#          'cannellini', 'dough', 'soup', 'spring', 'sriracha', 'leeks',
#          'prawns', 'grass', 'grating', 'poppy', 'lemongrass', 'kale',
#          'jicama', 'ham', 'noodles', 'molasses', 'refried', 'ricotta',
#          'roll', 'ranch', 'tuna', 'yeast', 'wonton', 'warm', 'bags',
#          'belly', 'marjoram', 'maple', 'napa', 'mussels', 'mung',
#          'mayonnaisee', 'mayonnaise', 'mace', 'macaroni', 'leaves',
#          'kalamata', 'kaffir', 'italian', 'halibut', 'hair', 'sausages',
#          'salmon', 'greens', 'shiitake', 'sherry', 'semolina', 'pumpkin',
#          'prunes', 'flakes', 'elbow', 'eggplants', 'dijon', 'sprouts',
#          'currant', 'crumb', 'cranberries', 'crabmeat', 'cornflour',
#          'peaches', 'pasta', 'parsnips', 'parmesan', 'paper', 'orzo',
#          'oranges', 'orangepepper', 'coffee', 'chorizo', 'chops',
#          'chocolate', 'tamarind', 'taco', 'syrup', 'sweet', 'strawberries',
#          'cherries', 'caraway', 'buttermilk', 'apricot', 'apple', 'angel',
#          'phyllo', 'udon'], dtype=object),
#   array(['sugar', 'flour', 'egg', 'salt', 'butter', 'baking', 'milk',
#          'powder', 'vanilla', 'water', 'cream', 'oil', 'corn', 'soda',
#          'cinnamon', 'vegetable', 'buttermilk', 'yeast', 'lemon', 'cheese',
#          'heavy', 'warm', 'chocolate', 'cooking', 'spray', 'juice',
#          'yellow', 'whipping', 'meal', 'starch', 'orange', 'almond',
#          'bread', 'nutmeg', 'raisins', 'cornmeal', 'zest', 'pepper',
#          'shortening', 'syrup', 'pecans', 'honey', 'sour', 'onion', 'olive',
#          'seeds', 'peacheses', 'tartar', 'beans', 'margarine', 'cheddar',
#          'half', 'condensed', 'potatoes', 'peel', 'cocoa', 'yogurt', 'rum',
#          'coconut', 'ice', 'pure', 'rice', 'apples', 'cold', 'wheat',
#          'ricotta', 'canola', 'bananas', 'cayenne', 'bourbon', 'whiskey',
#          'hazelnuts', 'walnuts', 'peanut', 'black', 'cake', 'bacon',
#          'strawberries', 'chili', 'garlic', 'raspberries', 'halves',
#          'ginger', 'brandy', 'sesame', 'chicken', 'whipped', 'pecan',
#          'sticks', 'coffee', 'sauce', 'shrimp', 'peaches', 'anise',
#          'seasoning', 'breadcrumbs', 'caraway', 'flakes', 'parmesan',
#          'morsels', 'lime', 'cumin', 'chives', 'cloves', 'golden', 'oats',
#          'wafers', 'mint', 'liver', 'maple', 'red', 'hot', 'cardamom',
#          'blueberries', 'boiling', 'vinegar', 'ham', 'piecrusts',
#          'molasses', 'redpepper', 'scallions', 'cherries', 'blackberries',
#          'sage', 'tea', 'semolina', 'thyme', 'allspice', 'wine', 'paprika',
#          'pineapple', 'gelatin', 'pistachios', 'mustard', 'espresso',
#          'dough', 'grits', 'fraîche', 'crème', 'kernel', 'ghee', 'pork',
#          'pears', 'parsley', 'cognac', 'celery', 'tomatoes', 'broth',
#          'crackers', 'cranberries', 'teas', 'carrots', 'star', 'sausage',
#          'curry', 'lard', 'mango', 'pumpkin', 'rosemary', 'baguette',
#          'basil', 'tabasco', 'cashew', 'swiss', 'sherry', 'spinach',
#          'cabbage', 'seed', 'sauces', 'dipping', 'dijon', 'cornflour',
#          'beer', 'turkey', 'cookies', 'mushrooms', 'poppy', 'polenta',
#          'fruit', 'fennel', 'rind', 'ribs', 'white', 'apricot', 'leeks',
#          'nuts', 'olives', 'liqueur', 'phyllo', 'pesto', 'crawfish',
#          'cottage', 'mayonaise', 'masa', 'harina', 'kernels', 'coriander',
#          'crab', 'saffron', 'salad', 'cilantro', 'sprigs', 'squash',
#          'sriracha', 'spices', 'sheets', 'crumb', 'cubes', 'spice',
#          'snapper', 'tumeric', 'vegetables', 'biscuits', 'vodka',
#          'beansprouts', 'beef', 'bags', 'zucchini', 'sweet', 'stock',
#          'tortilla', 'bean', 'shiitake', 'shoulder', 'sausages', 'currant',
#          'pimentos', 'greenpepper', 'kidney', 'kimchi', 'pinenuts', 'puff',
#          'fat', 'rolls', 'elbow', 'eggplant', 'gruyere', 'pepperoni',
#          'macaroni', 'pastry', 'mascarpone', 'oregano', 'mace', 'oranges',
#          'lettuce', 'apple', 'andouille', 'mushroom', 'asiago'],
#         dtype=object),
#   array(['pepper', 'salt', 'onion', 'garlic', 'black', 'oil', 'red',
#          'tomatoes', 'olive', 'rice', 'cayenne', 'chicken', 'sauce',
#          'thyme', 'water', 'cumin', 'flour', 'parsley', 'vegetable',
#          'paprika', 'butter', 'broth', 'oregano', 'juice', 'lemon', 'bay',
#          'tomato', 'cheese', 'sugar', 'chili', 'cilantro', 'celery',
#          'shrimp', 'wine', 'greenpepper', 'egg', 'beef', 'cream', 'ginger',
#          'basil', 'vinegar', 'lime', 'powder', 'corn', 'carrots', 'milk',
#          'green', 'paste', 'coriander', 'hot', 'cinnamon', 'stock',
#          'cooking', 'potatoes', 'seasoning', 'beans', 'redpepper', 'bacon',
#          'curry', 'canola', 'pork', 'bean', 'bell', 'spray', 'white',
#          'yogurt', 'ribs', 'mustard', 'tortilla', 'parmesan', 'sausage',
#          'sour', 'chile', 'worcestershire', 'seeds', 'allspice',
#          'scallions', 'seed', 'bread', 'soy', 'masala', 'olives', 'coconut',
#          'peas', 'okra', 'saffron', 'rosemary', 'heavy', 'nutmeg',
#          'cucumber', 'andouille', 'mint', 'peanut', 'starch', 'spinach',
#          'turmeric', 'shallots', 'buttermilk', 'half', 'cabbage', 'cheddar',
#          'jack', 'lettuce', 'lamb', 'honey', 'turkey', 'tumeric', 'orange',
#          'lean', 'fennel', 'threads', 'pasta', 'ham', 'feta', 'cardamom',
#          'capers', 'baking', 'poblano', 'mushrooms', 'mozzarella',
#          'zucchini', 'crab', 'eggplant', 'kidney', 'breadcrumbs', 'cloves',
#          'mushroom', 'tabasco', 'whipping', 'avocado', 'kernels', 'fish',
#          'lentils', 'clams', 'penne', 'chiles', 'raisins', 'cold', 'zest',
#          'chickpeas', 'salsa', 'sage', 'dijon', 'ketchup', 'spaghetti',
#          'monterey', 'chuck', 'chipotle', 'yellow', 'tarragon', 'marjoram',
#          'steak', 'meat', 'mayonaise', 'enchilada', 'serrano', 'liver',
#          'cornmeal', 'grits', 'beer', 'quinoa', 'purée', 'sesame', 'dill',
#          'sprigs', 'pinto', 'couscous', 'linguine', 'clove', 'chorizo',
#          'ancho', 'broccoli', 'tomatillos', 'almond', 'sticks', 'meal',
#          'rolls', 'horseradish', 'anchovy', 'boiling', 'wedges', 'apricot',
#          'bouillon', 'greens', 'file', 'garbanzo', 'flank', 'collard',
#          'cod', 'clam', 'chops', 'chives', 'crawfish', 'shoulder', 'sherry',
#          'shortening', 'chilees', 'baguette', 'tenderloin', 'butt',
#          'margarine', 'catfish', 'mussels', 'rib', 'hair', 'salmon', 'lard',
#          'crabmeat', 'sriracha', 'mace', 'short', 'orangepepper', 'polenta',
#          'tuna', 'swiss', 'sweet', 'chees', 'bulb', 'cannellini',
#          'cauliflower', 'stew', 'angel', 'halibut', 'leeks', 'sausages',
#          'artichokes', 'vegetables', 'prosciutto', 'squash', 'escarole',
#          'salad', 'grass', 'scallops', 'gallo', 'goat', 'husks', 'bow',
#          'vermouth', 'beets', 'wedge', 'guacamole', 'sea', 'snapper',
#          'kalamata', 'spice', 'spices', 'soda', 'pinenuts', 'pimentos',
#          'pico', 'peel', 'loin', 'pistachios', 'pineapple', 'sirloin',
#          'fat', 'creole', 'currant', 'mayonnaisee', 'mexican', 'caraway',
#          'szechwan', 'noodles', 'brown', 'tofu', 'tilapia', 'tie',
#          'peaches', 'tea', 'brandy', 'wrappers', 'yeast', 'wonton',
#          'whiskey', 'warm', 'artichoke', 'apple', 'asiago', 'asparagus',
#          'orzo', 'nuts', 'oysters', 'peacheses', 'oyster', 'pods', 'mango',
#          'napa', 'piecrusts', 'phyllo', 'pesto', 'marinara', 'radishes',
#          'pumpkin', 'lemongrass', 'lobster', 'masa', 'italian', 'ice',
#          'rum', 'rigatoni', 'kale', 'kernel', 'provolone', 'ricotta',
#          'harina', 'gingerroot', 'gochujang', 'grating', 'shells', 'sauces',
#          'dough', 'dipping', 'cubes', 'fettucine', 'finely', 'shoots',
#          'dressing', 'double', 'guajillo', 'kaffir', 'golden', 'gruyere',
#          'roll', 'verde', 'base', 'bags', 'bamboo', 'yellowpepper', 'stems',
#          'cashew', 'chard', 'toasted', 'butternut', 'spring', 'crackers',
#          'tequila', 'bourbon', 'vodka', 'biscuits', 'adobo'], dtype=object),
#   array(['oil', 'olive', 'salt', 'garlic', 'pepper', 'onion', 'cheese',
#          'tomatoes', 'lemon', 'black', 'parsley', 'wine', 'parmesan',
#          'basil', 'juice', 'water', 'rice', 'chicken', 'broth', 'oregano',
#          'flour', 'egg', 'butter', 'red', 'bread', 'thyme', 'olives',
#          'redpepper', 'tomato', 'potatoes', 'carrots', 'vinegar', 'sauce',
#          'sugar', 'paste', 'vegetable', 'bay', 'beans', 'mozzarella',
#          'capers', 'shrimp', 'spinach', 'pasta', 'spray', 'greenpepper',
#          'cooking', 'feta', 'paprika', 'cream', 'rosemary', 'celery',
#          'pinenuts', 'mint', 'seasoning', 'milk', 'zucchini', 'cilantro',
#          'shallots', 'zest', 'eggplant', 'green', 'chili', 'ricotta',
#          'mustard', 'cucumber', 'corn', 'cumin', 'anchovy', 'peas', 'stock',
#          'beef', 'mushrooms', 'mushroom', 'cayenne', 'sausage', 'fennel',
#          'linguine', 'spaghetti', 'breadcrumbs', 'ribs', 'yeast',
#          'artichokes', 'hot', 'kalamata', 'penne', 'yogurt', 'dijon',
#          'seeds', 'cinnamon', 'baguette', 'warm', 'coriander', 'lamb',
#          'honey', 'pork', 'tuna', 'arugula', 'bacon', 'orange', 'saffron',
#          'lime', 'leeks', 'raisins', 'lettuce', 'chickpeas', 'broccoli',
#          'mussels', 'heavy', 'threads', 'squash', 'ham', 'nutmeg',
#          'cannellini', 'yellow', 'chives', 'sage', 'clams', 'scallions',
#          'turkey', 'prosciutto', 'chile', 'asparagus', 'couscous', 'half',
#          'bulb', 'tortilla', 'pizza', 'pancetta', 'sprigs', 'bean',
#          'chorizo', 'kale', 'polenta', 'italian', 'whipping', 'white',
#          'almond', 'goat', 'ginger', 'doughs', 'liver', 'peel', 'sour',
#          'yellowpepper', 'swiss', 'cabbage', 'rigatoni', 'canola', 'golden',
#          'tarragon', 'soy', 'chard', 'tenderloin', 'fettucine', 'dill',
#          'walnuts', 'powder', 'cheddar', 'bow', 'sherry', 'tie', 'noodles',
#          'pesto', 'avocado', 'starch', 'herbs', 'worcestershire',
#          'scallops', 'crumb', 'chuck', 'cornmeal', 'lean', 'wedge',
#          'andouille', 'clam', 'orzo', 'chiles', 'salmon', 'sea', 'seed',
#          'butternut', 'chees', 'cauliflower', 'mayonaise', 'garbanzo',
#          'greens', 'grits', 'cold', 'vermouth', 'radicchio', 'pimentos',
#          'curry', 'meat', 'kernels', 'bell', 'beer', 'lentils', 'marinara',
#          'marjoram', 'boiling', 'salsa', 'buttermilk', 'purée', 'rolls',
#          'fish', 'gruyere', 'dough', 'turmeric', 'escarole', 'angel',
#          'sticks', 'chops', 'sheets', 'meal', 'cod', 'fontina', 'asiago',
#          'watercress', 'hair', 'okra', 'tumeric', 'pastry', 'clove', 'puff',
#          'apples', 'bouillon', 'vinaigrette', 'spices', 'sausages',
#          'allspice', 'provolone', 'coconut', 'baking', 'margarine', 'steak',
#          'creole', 'sesame', 'kidney', 'snapper', 'cloves', 'chipotles',
#          'sirloin', 'cardamom', 'pepperoni', 'parsnips', 'serrano',
#          'radishes', 'vegetables', 'adobo', 'artichoke', 'phyllo',
#          'pistachios', 'kimchi', 'halibut', 'jack', 'sriracha', 'lobster',
#          'finely', 'stew', 'tabasco', 'mascarpone', 'hazelnuts', 'leaves',
#          'verde', 'poblano', 'shiitake', 'masala', 'cognac', 'kernel',
#          'mayonnaise', 'squid', 'gruyère', 'wheat', 'elbow', 'enchilada',
#          'macaroni', 'eggplants', 'crust', 'mexican', 'crab', 'shoulder',
#          'toasted', 'collard', 'crackers', 'brandy', 'tomatillos',
#          'semolina', 'tofu', 'orangepepper', 'pears', 'refried', 'turnips',
#          'brown', 'pecans', 'coffee', 'wedges', 'asian', 'beansprouts',
#          'shortening', 'cornflour', 'cottage', 'crawfish', 'mango',
#          'ketchup', 'lemongrass', 'halves', 'stems', 'horseradish',
#          'kaffir', 'maple', 'american', 'grating', 'fat', 'fenugreek',
#          'sunflower', 'syrup', 'gallo', 'flakes', 'fruit', 'guacamole',
#          'guajillo', 'flank', 'gelatin', 'dressing', 'daikon', 'currant',
#          'jicama', 'miso', 'shells', 'ranch', 'caraway', 'pinto', 'butt',
#          'salad', 'pico', 'peanut', 'chilees', 'paper', 'oranges',
#          'tequila', 'tilapia', 'catfish', 'cashews', 'nori', 'nectar',
#          'soda', 'monterey', 'chipotle', 'pecan', 'piecrusts', 'quinoa',
#          'apple', 'apricot', 'prawns', 'pods', 'vodka', 'biscuits', 'agave'],
#         dtype=object),
#   array(['salt', 'pepper', 'onion', 'water', 'rice', 'butter', 'garlic',
#          'sugar', 'oil', 'juice', 'chicken', 'black', 'lemon', 'flour',
#          'tomatoes', 'vegetable', 'egg', 'milk', 'potatoes', 'cream',
#          'broth', 'lime', 'corn', 'chili', 'cilantro', 'vinegar', 'ginger',
#          'red', 'carrots', 'parsley', 'seasoning', 'wine', 'bacon', 'bay',
#          'cinnamon', 'paprika', 'shrimp', 'mustard', 'beef', 'sauce',
#          'peas', 'thyme', 'celery', 'greenpepper', 'beans', 'pork',
#          'cooking', 'seeds', 'coconut', 'mayonaise', 'curry', 'sour',
#          'yogurt', 'cumin', 'chile', 'paste', 'mushrooms', 'cabbage',
#          'scallions', 'mint', 'orange', 'cucumber', 'cayenne', 'stock',
#          'oregano', 'sausage', 'tomato', 'green', 'heavy', 'coriander',
#          'white', 'buttermilk', 'avocado', 'spray', 'tortilla', 'starch',
#          'powder', 'shallots', 'hot', 'cardamom', 'redpepper', 'half',
#          'sticks', 'breadcrumbs', 'salsa', 'almond', 'ham', 'raisins',
#          'ribs', 'clove', 'nutmeg', 'bread', 'peanut', 'honey', 'cold',
#          'whipping', 'bean', 'ice', 'tomatillos', 'mango', 'basil',
#          'cornmeal', 'okra', 'vanilla', 'dill', 'dijon', 'chiles', 'zest',
#          'tumeric', 'sprigs', 'spinach', 'saffron', 'leeks', 'rosemary',
#          'greens', 'jack', 'lamb', 'sesame', 'olives', 'cloves', 'canola',
#          'pineapple', 'tea', 'masala', 'monterey', 'seed', 'ketchup',
#          'fennel', 'lentils', 'peacheses', 'chives', 'chops', 'cheese',
#          'bell', 'worcestershire', 'turkey', 'serrano', 'lettuce',
#          'mushroom', 'grits', 'apples', 'brandy', 'zucchini', 'allspice',
#          'sausages', 'ghee', 'catfish', 'nori', 'collard', 'pistachios',
#          'cubes', 'noodles', 'salmon', 'crab', 'whiskey', 'star', 'beer',
#          'wedge', 'horseradish', 'tarragon', 'bourbon', 'boiling',
#          'yellowpepper', 'warm', 'anise', 'threads', 'teas', 'andouille',
#          'squash', 'spaghetti', 'salad', 'biscuits', 'dressing',
#          'asparagus', 'yeast', 'shortening', 'creole', 'couscous', 'capers',
#          'pecans', 'ancho', 'yellow', 'sage', 'tenderloin', 'butternut',
#          'broccoli', 'pods', 'walnuts', 'ricotta', 'refried', 'cashew',
#          'chipotle', 'fraîche', 'tabasco', 'daikon', 'nuts', 'napa',
#          'crème', 'condensed', 'crawfish', 'pears', 'peaches', 'chocolate',
#          'bouillon', 'mayonnaisee', 'steak', 'meal', 'sherry', 'liqueur',
#          'liver', 'turmeric', 'bags', 'wedges', 'baguette', 'beets', 'lard',
#          'kernel', 'kernels', 'kidney', 'lean', 'shoulder', 'husks',
#          'sheets', 'shiitake', 'syrup', 'sunflower', 'mussels', 'golden',
#          'spices', 'strawberries', 'butt', 'apricot', 'asiago', 'radishes',
#          'puff', 'blackberries', 'poblano', 'chickpeas', 'pesto', 'pinto',
#          'pastry', 'chorizo', 'cookies', 'clam', 'coffee', 'bulb',
#          'vegetables', 'raspberries', 'crabmeat', 'cherries', 'toasted',
#          'chuck', 'pasta', 'blueberries', 'quinoa', 'pure', 'cannellini',
#          'tuna', 'tequila', 'chees', 'cauliflower', 'miso', 'maple',
#          'margarine', 'squid', 'oysters', 'nectar', 'file', 'finely',
#          'guacamole', 'mozzarella', 'shells', 'mirin', 'turnips', 'kale',
#          'baking', 'belly', 'vermouth', 'agave', 'cranberries', 'orzo',
#          'fenugreek', 'flank', 'szechwan', 'fat', 'tamarind', 'halibut',
#          'guajillo', 'spice', 'soy', 'gelatin', 'gallo', 'sweet', 'gruyere',
#          'gingerroot', 'snapper', 'jicama', 'watercress', 'lemongrass',
#          'wheat', 'loin', 'soda', 'soup', 'mace', 'meat', 'mascarpone',
#          'mayonnaise', 'hazelnuts', 'fruit', 'olive', 'oranges', 'cashews',
#          'tie', 'caraway', 'pico', 'parsnips', 'paneer', 'cod', 'peel',
#          'crackers', 'cotija', 'pancetta', 'chipotles', 'artichokes',
#          'cachaca', 'polenta', 'bow', 'prosciutto', 'vinaigrette', 'adobo',
#          'wrappers', 'wonton', 'apple', 'arugula', 'pumpkin', 'purée',
#          'radicchio', 'angel', 'prunes', 'rind', 'phyllo', 'piecrusts',
#          'pimentos', 'pinenuts', 'pizza', 'poppy', 'pecan', 'penne',
#          'rolls', 'konbu', 'shoots', 'sirloin', 'kaffir', 'sake', 'sea',
#          'scallops', 'sauces', 'semolina', 'morsels', 'molasses',
#          'orangepepper', 'paper', 'herbs', 'kalamata', 'lobster',
#          'macaroni', 'kimchi', 'cognac', 'clams', 'cocoa', 'tilapia',
#          'cheddar', 'choy', 'tofu', 'bamboo', 'vodka', 'bok', 'brown',
#          'bananas', 'beansprouts', 'udon', 'verde', 'double', 'dough',
#          'elbow', 'enchilada', 'feta', 'swiss', 'flakes', 'galangal',
#          'garbanzo', 'grass', 'hair', 'halves', 'crumb', 'cottage', 'crust',
#          'cornflour', 'dipping', 'amchur'], dtype=object),
#   array(['sauce', 'garlic', 'oil', 'sugar', 'onion', 'soy', 'rice', 'fish',
#          'lime', 'pepper', 'salt', 'juice', 'water', 'ginger', 'cilantro',
#          'vegetable', 'chili', 'chicken', 'peanut', 'vinegar', 'coconut',
#          'milk', 'carrots', 'shrimp', 'egg', 'curry', 'black', 'scallions',
#          'red', 'paste', 'chile', 'basil', 'noodles', 'butter', 'broth',
#          'lemon', 'mint', 'shallots', 'hot', 'pork', 'olive', 'corn',
#          'lemongrass', 'stock', 'green', 'tomatoes', 'lettuce', 'powder',
#          'canola', 'redpepper', 'coriander', 'worcestershire', 'tomato',
#          'beansprouts', 'flour', 'asian', 'cabbage', 'beef', 'cooking',
#          'starch', 'tofu', 'bay', 'wine', 'honey', 'cucumber', 'hoisin',
#          'ketchup', 'mirin', 'potatoes', 'anise', 'peas', 'star', 'cumin',
#          'sake', 'beans', 'ribs', 'celery', 'sesame', 'zucchini', 'seeds',
#          'mushrooms', 'grass', 'oyster', 'greenpepper', 'steak',
#          'seasoning', 'orange', 'mushroom', 'kaffir', 'mustard', 'tortilla',
#          'sriracha', 'spray', 'cinnamon', 'wedges', 'serrano', 'thyme',
#          'tenderloin', 'zest', 'adobo', 'oregano', 'sprigs', 'cream',
#          'paper', 'cayenne', 'salmon', 'spinach', 'spice', 'white',
#          'sherry', 'bean', 'sticks', 'paprika', 'parsley', 'flank',
#          'mayonaise', 'squid', 'galangal', 'clove', 'chiles', 'bouillon',
#          'bird', 'vietnamese', 'breadcrumbs', 'chipotle', 'shiitake',
#          'prawns', 'radishes', 'pineapple', 'eggplant', 'sprouts', 'greens',
#          'mung', 'ham', 'mango', 'sour', 'turkey', 'belly', 'bread', 'udon',
#          'turmeric', 'sirloin', 'chestnuts', 'cashews', 'warm', 'dashi',
#          'sausage', 'rolls', 'daikon', 'chops', 'cheese', 'loin',
#          'andouille', 'avocado', 'stems', 'tamarind', 'salsa', 'salad',
#          'crabmeat', 'roll', 'spring', 'wrappers', 'allspice', 'boiling',
#          'vegetables', 'bacon', 'beer', 'bok', 'broccoli', 'toasted',
#          'choy', 'chilees', 'cornflour', 'cold', 'raisins', 'enchilada',
#          'wedge', 'molasses', 'gingerroot', 'jack', 'napa', 'flakes',
#          'dijon', 'crab', 'bourbon', 'bell', 'chuck', 'cloves', 'chipotles',
#          'chives', 'bananas', 'cauliflower', 'jicama', 'kernels', 'herbs',
#          'mayonnaise', 'miso', 'grits', 'monterey', 'halibut', 'parmesan',
#          'pinto', 'nutmeg', 'nori', 'asparagus', 'watercress', 'whiskey',
#          'konbu', 'leaves', 'lean', 'leeks', 'lamb', 'meat', 'nectar',
#          'olives', 'pizza', 'purée', 'pasta', 'sausages', 'baguette',
#          'baking', 'yogurt', 'yellowpepper', 'cheddar', 'catfish',
#          'szechwan', 'bamboo', 'agave', 'almond', 'clam', 'shoots',
#          'snapper', 'chickpeas', 'sauces', 'eggplants', 'dill', 'rind',
#          'dipping', 'linguine', 'gallo', 'okra', 'fennel', 'file', 'pico',
#          'quinoa', 'penne', 'fettucine', 'pumpkin', 'poblano', 'chocolate',
#          'squash', 'ancho', 'lobster', 'anchovy', 'wheat', 'kernel',
#          'margarine', 'guacamole', 'heavy', 'mayonnaisee', 'pepperoni',
#          'oysters', 'paneer', 'mozzarella', 'gelatin', 'nuts', 'garbanzo',
#          'lard', 'kimchi', 'apples', 'arugula', 'ranch', 'dressing',
#          'creole', 'sea', 'scallops', 'yeast', 'radicchio', 'crumb', 'soda',
#          'clams', 'sunflower', 'chard', 'cashew', 'tabasco', 'sweet',
#          'swiss', 'tilapia', 'tomatillos', 'yellow', 'turnips', 'tuna',
#          'tumeric', 'bonito', 'bags', 'tarragon', 'cardamom', 'teas',
#          'tequila', 'tea', 'butt', 'buttermilk', 'capers', 'sage',
#          'rosemary', 'shoulder', 'coffee', 'crackers'], dtype=object),
#   array(['oil', 'sauce', 'sesame', 'soy', 'garlic', 'pepper', 'onion',
#          'sugar', 'ginger', 'corn', 'rice', 'starch', 'salt', 'water',
#          'vinegar', 'vegetable', 'seeds', 'egg', 'wine', 'chicken',
#          'scallions', 'black', 'red', 'chili', 'peanut', 'toasted', 'broth',
#          'carrots', 'honey', 'white', 'oyster', 'noodles', 'pork', 'juice',
#          'beef', 'cabbage', 'canola', 'flour', 'stock', 'hoisin', 'ketchup',
#          'powder', 'cilantro', 'redpepper', 'peas', 'tofu', 'broccoli',
#          'cooking', 'mushroom', 'orange', 'olive', 'sriracha', 'steak',
#          'mirin', 'beansprouts', 'sake', 'shrimp', 'flank', 'spinach',
#          'lime', 'shiitake', 'fish', 'bean', 'spice', 'butter', 'paste',
#          'napa', 'ribs', 'base', 'celery', 'gochujang', 'wrappers',
#          'kimchi', 'mushrooms', 'baking', 'chile', 'sherry', 'wonton',
#          'cucumber', 'hot', 'shoots', 'bok', 'szechwan', 'green', 'lemon',
#          'choy', 'lettuce', 'bamboo', 'chestnuts', 'shallots', 'spray',
#          'greenpepper', 'tenderloin', 'cold', 'potatoes', 'miso',
#          'zucchini', 'sirloin', 'soda', 'asparagus', 'coconut', 'tomato',
#          'zest', 'udon', 'mint', 'salmon', 'milk', 'mung', 'sprouts',
#          'sprigs', 'spaghetti', 'gingerroot', 'warm', 'syrup', 'rib',
#          'loin', 'short', 'curry', 'linguine', 'nectar', 'vegetables',
#          'beans', 'basil', 'agave', 'yellowpepper', 'yeast', 'cayenne',
#          'pineapple', 'greens', 'kale', 'leeks', 'daikon', 'oranges',
#          'cream', 'cumin', 'meat', 'chiles', 'chives', 'coriander',
#          'turkey', 'boiling', 'belly', 'seasoning', 'shoulder', 'bell',
#          'eggplant', 'apple', 'angel', 'anise', 'star', 'squid', 'bouillon',
#          'buttermilk', 'breadcrumbs', 'serrano', 'cauliflower', 'cashews',
#          'cashew', 'chops', 'peel', 'hair', 'salad', 'sauces', 'parsley',
#          'dipping', 'nuts', 'cornflour', 'lemongrass', 'tumeric',
#          'turmeric', 'avocado', 'tuna', 'tomatoes', 'tortilla',
#          'vietnamese', 'butt', 'spices', 'spring', 'worcestershire',
#          'sausage', 'chilees', 'shells', 'shortening', 'swiss', 'grass',
#          'heavy', 'chard', 'snapper', 'sour', 'clove', 'raisins',
#          'radishes', 'kernels', 'ham', 'cheese', 'rind', 'roll', 'clam',
#          'chuck', 'clams', 'pasta', 'paprika', 'pears', 'olives',
#          'eggplants', 'stew', 'ancho', 'tea', 'tilapia', 'galangal',
#          'apples', 'lentils', 'lobster', 'maple', 'molasses', 'nutmeg',
#          'mustard', 'mayonnaise', 'lean', 'asian', 'walnuts', 'watercress',
#          'wedge', 'baguette', 'bacon'], dtype=object),
#   array(['cheese', 'pepper', 'onion', 'salt', 'cream', 'parmesan', 'garlic',
#          'cheddar', 'black', 'sauce', 'tortilla', 'butter', 'rice', 'egg',
#          'tomatoes', 'sour', 'oil', 'chicken', 'chili', 'salsa',
#          'mozzarella', 'cilantro', 'milk', 'flour', 'beef', 'broth',
#          'tomato', 'seasoning', 'water', 'parsley', 'bean', 'jack', 'corn',
#          'olive', 'basil', 'cooking', 'cumin', 'spray', 'vegetable',
#          'beans', 'monterey', 'oregano', 'chile', 'enchilada', 'red',
#          'breadcrumbs', 'olives', 'spinach', 'bacon', 'ricotta', 'bread',
#          'mushrooms', 'wine', 'green', 'noodles', 'potatoes', 'heavy',
#          'mexican', 'feta', 'greenpepper', 'lettuce', 'mushroom', 'pasta',
#          'redpepper', 'thyme', 'refried', 'avocado', 'lemon', 'hot',
#          'sausage', 'pizza', 'lean', 'lime', 'juice', 'grits', 'cayenne',
#          'mayonaise', 'paprika', 'marinara', 'chives', 'paste', 'whipping',
#          'shallots', 'cottage', 'soup', 'turkey', 'carrots', 'ham',
#          'shrimp', 'stock', 'half', 'white', 'worcestershire', 'peas',
#          'nutmeg', 'mustard', 'scallions', 'goat', 'artichokes', 'canola',
#          'guacamole', 'sugar', 'kernels', 'gruyere', 'eggplant', 'bay',
#          'spaghetti', 'fontina', 'grating', 'kernel', 'verde', 'yogurt',
#          'pinto', 'leeks', 'yellow', 'rosemary', 'penne', 'prosciutto',
#          'dressing', 'cucumber', 'celery', 'zucchini', 'powder', 'crumb',
#          'fettucine', 'american', 'pimentos', 'broccoli', 'poblano', 'meal',
#          'margarine', 'pico', 'cornmeal', 'gallo', 'chipotles', 'chiles',
#          'pork', 'crust', 'rolls', 'buttermilk', 'adobo', 'zest',
#          'pepperoni', 'vinegar', 'swiss', 'doughs', 'taco', 'gruyère',
#          'provolone', 'cauliflower', 'sprigs', 'asparagus', 'tie', 'bow',
#          'tabasco', 'dijon', 'peanut', 'rigatoni', 'ranch', 'boiling',
#          'vegetables', 'pesto', 'squash', 'chipotle', 'dill', 'baguette',
#          'crackers', 'cinnamon', 'chorizo', 'beer', 'pancetta',
#          'tomatillos', 'salad', 'herbs', 'bell', 'starch', 'fat', 'sirloin',
#          'baking', 'wedges', 'dough', 'mint', 'meat', 'kidney', 'shells',
#          'sheets', 'finely', 'wrappers', 'yellowpepper', 'pastry', 'warm',
#          'saffron', 'linguine', 'wonton', 'yeast', 'pinenuts', 'tartar',
#          'biscuits', 'puff', 'honey', 'threads', 'radishes', 'phyllo',
#          'crab', 'crawfish', 'couscous', 'angel', 'cotija', 'almond',
#          'hair', 'kale', 'mayonnaise', 'marjoram', 'mayonnaisee', 'brandy',
#          'capers', 'butternut', 'tofu', 'kalamata', 'polenta', 'lard',
#          'chuck', 'macaroni', 'chard', 'apples', 'shoulder', 'sherry',
#          'seed', 'lamb', 'andouille', 'arugula', 'artichoke', 'fruit',
#          'escarole', 'chestnuts', 'salmon', 'cold', 'tarragon', 'sweet',
#          'peel', 'vanilla', 'vinaigrette', 'pecans', 'oysters', 'cabbage',
#          'crabmeat', 'elbow', 'ancho', 'sauces', 'serrano', 'liver',
#          'mango', 'mascarpone', 'masa', 'chees', 'semolina', 'sea', 'choy',
#          'seeds', 'husks', 'ketchup', 'scallops', 'ice', 'crème', 'ginger',
#          'shortening', 'soy', 'spices', 'steak', 'dipping', 'anchovy',
#          'whiskey', 'watercress', 'beansprouts', 'wheat', 'curry',
#          'currant', 'fraîche', 'fennel', 'sausages', 'italian', 'halves',
#          'halibut', 'greens', 'harina', 'sesame', 'gelatin', 'hazelnuts',
#          'sticks', 'strawberries', 'clam', 'clams', 'cod', 'bulb',
#          'bourbon', 'tuna', 'tumeric', 'cashews', 'vodka', 'bok', 'pecan',
#          'bouillon', 'parsnips', 'orangepepper', 'orange', 'quinoa', 'sage',
#          'leaves', 'ribs', 'cannellini', 'cake', 'butt', 'turmeric',
#          'vermouth', 'allspice'], dtype=object)],
#  [array([0.88964346, 0.83870968, 0.75721562, 0.73514431, 0.62818336,
#          0.62818336, 0.61290323, 0.56876061, 0.51952462, 0.35483871,
#          0.33786078, 0.32427844, 0.29711375, 0.28692699, 0.28013582,
#          0.27674024, 0.27504244, 0.24278438, 0.19354839, 0.1901528 ,
#          0.18845501, 0.16977929, 0.15449915, 0.14601019, 0.14431239,
#          0.14091681, 0.13582343, 0.13412564, 0.13412564, 0.13242784,
#          0.12733447, 0.12393888, 0.12224109, 0.12224109, 0.12224109,
#          0.1188455 , 0.11714771, 0.11714771, 0.10696095, 0.10526316,
#          0.10356537, 0.10186757, 0.10186757, 0.10016978, 0.09337861,
#          0.08828523, 0.08149406, 0.07979626, 0.07809847, 0.07809847,
#          0.06960951, 0.06960951, 0.06960951, 0.06451613, 0.06451613,
#          0.06112054, 0.05942275, 0.05942275, 0.05942275, 0.05602716,
#          0.05602716, 0.05602716, 0.05602716, 0.05432937, 0.04923599,
#          0.04923599, 0.0475382 , 0.04584041, 0.04414261, 0.04414261,
#          0.04414261, 0.04244482, 0.04244482, 0.04244482, 0.04244482,
#          0.04244482, 0.04074703, 0.04074703, 0.03904924, 0.03904924,
#          0.03735144, 0.03735144, 0.03565365, 0.03565365, 0.03395586,
#          0.03395586, 0.03225806, 0.03056027, 0.03056027, 0.03056027,
#          0.03056027, 0.03056027, 0.02886248, 0.02886248, 0.02716469,
#          0.02716469, 0.02546689, 0.02546689, 0.02546689, 0.0237691 ,
.0042735 , 0.0042735 , 0.0042735 , 0.0042735 , 0.0042735 ,
#          0.0042735 , 0.0042735 , 0.0042735 , 0.0042735 , 0.0042735 ,
#          0.0042735 , 0.0042735 , 0.0042735 , 0.0042735 , 0.0042735 ,
#          0.0042735 , 0.0042735 , 0.0042735 , 0.0042735 , 0.0042735 ,
#          0.0042735 , 0.002849  , 0.002849  , 0.002849  , 0.002849  ,
#          0.002849  , 0.002849  , 0.002849  , 0.002849  , 0.002849  ,
#          0.002849  , 0.002849  , 0.002849  , 0.002849  , 0.002849  ,
#          0.002849  , 0.002849  , 0.002849  , 0.002849  , 0.002849  ,
#          0.002849  , 0.002849  , 0.002849  , 0.002849  , 0.002849  ,
#          0.002849  , 0.002849  , 0.002849  , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ,
#          0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 , 0.0014245 ])])

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# What do these cluster centers represent ?<br>
# Is there anything interesting about recipe cluster centers ?<br>
# </span>

# %% [markdown]
# <span style="color:green;">They represent ingredients used in similar recipes? Does this mean that lots of recipes with 'onion', also ohave'salt', 'garlic', 'oil'?  </span>

# %% [markdown]
# ### Plot Clusters
#
# Let's plot our clusters to see if we have to adjust any of the clustering parameters.
#
# Since we can't plot in $500$ dimensions, we should use `PCA` to look at our clusters in $2D$ and $3D$.

# %%
# TODO: PCA to reduce the dimensions of our feature space
pca = PCA(n_components=2)
dim_red_ingredients = pca.fit_transform(ingredients_vector)
x = dim_red_ingredients[:,0]
y=dim_red_ingredients[:,1]
# TODO: plot clusters
plt.scatter(x,y, marker="o", c=clusters)
plt.show()

pca = PCA(n_components=3)
dim_red_ingredients = pca.fit_transform(ingredients_vector)
x = dim_red_ingredients[:,0]
y=dim_red_ingredients[:,1]
z=dim_red_ingredients[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y, z,marker="o", c=clusters)
plt.show()

# %% [markdown]
# ### Plot Silhouette Plots
#
# We can also check the quality of our clustering by looking at the silhouette plots that we get from calling:<br>
# `display_silhouette_plots(vectors, clusters)`.

# %%
display_silhouette_plots(ingredients_vector, clusters)

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# How many clusters did you end up with ?<br>
# How do they look ?<br>
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span>

# %% [markdown]
# ## Recipe Completion
#
# Ok. On to the main event.
#
# Let's create some recipes.
#
# We'll do this using a technique similar to what is used for movie/product recommendations. Given an initial set of ingredients, we'll look at recipes that have similar ingredients and "recommend" additional ingredients.
#
# We already have all of the recipes in our dataset encoded as `tf-idf` vectors. The rest of our algorithm will be something like:
# 1. Start with an initial set of ingredients
# 2. Encode ingredients
# 3. Find a set of recipes that are similar to our list of ingredients
# 4. Find common ingredients that are in the similar recipes, but not in our list of ingredients
# 5. Pick representative ingredient to add to recipe
# 6. Repeat
#
# Let's start.

# %% [markdown]
# ### 1. Initial list of ingredients
#
# This is just a string with ingredients:

# %%
recipe_seed_str = "tofu" # feel free to change this

# %% [markdown]
# ### 2. Encode ingredients
#
# Transform the string into a `tf-idf` vector:

# %%
# TODO: transform string into sparse vector

recipe_seed_vct = [0] # change this

# %% [markdown]
# ### 3. Find similar recipes
#
# The meat of the algorithm. No pun intended.
#
# In order to find similar recipes, we'll first calculate the distance between our current list of ingredients and all recipes in our dataset.
#
# We can start with euclidean distance and later try other kinds, but the overall processing will be the same:
#
# 1. Start with an empty list to store distances
# 2. Loop over the `tf-idf` recipe vectors and for each vector:
#    1. Subtract the ingredient list
#    2. Square the difference (to square a sparse matrix `A`, use `A.multiply(A)`)
#    3. Sum the terms of the result
#    4. Take the square root of the sum
#    5. Append to distance list
# 3. Find the indices of the smallest distances (this operation is called `argsort` and will give us the indices of the recipes that are most similar to our list of ingredients)
# 4. Check the recipes to see if they are indeed similar (`inverse_transform()` the vectors at the indices calculated above)

# %%
# argsort a list (get sequence of indices that would sort the list)
# https://stackoverflow.com/a/3382369
def argsort(L, reverse=False):
  return sorted(range(len(L)), key=L.__getitem__, reverse=reverse)

# %%
# TODO: list to keep distances
recipe_dists = []

# TODO: loop over vectors and append euclidean distances to list

# TODO: argsort list of distances to find indices of similar recipes

# TODO: check first 4 recipes

# %% [markdown]
# ### 4. Find ingredients to recommend
#
# We have a way to get a set of similar recipes with similar ingredients, and now want to find a *meaningful*, or *representative*, ingredient to add to our ingredients list.
#
# Let's consider ingredients in the $16$ most similar recipes. What we are trying to do is find an ingredient that is in a lot of these recipes, but not yet in our list of ingredients.
#
# There are many possible ways of doing this. We could count the number of times different ingredients show up in these $16$ recipes using Python dictionaries and/or sets, but what we're trying to do here is very similar to what a `TfidfVectorizer` does: calculate relative importance of terms in a series of documents.
#
# Let's re-encode these $16$ recipes using their own separate `TfidfVectorizer`, then sum the importance of each ingredient and look at ingredients with the highest importance scores.
#
# We could re-use the vectors/scores from the original `TfidfVectorizer`, but they're gonna be influenced by the relative frequencies of all of the ingredients that showed up in all of the recipes. Using a separate vectorizer is a little bit more precise.
#
# The steps we need to take are:
#
# 1. Separate the $16$ recipes most similar to our list of ingredients
#    1. We have lots of representations of our recipes, but `recipes` (list of strings) might be the easiest one to use here
# 2. Create a new `TfidfVectorizer` and encode the $16$ recipes
# 3. Sum the resulting vectors to get overall importance scores for each ingredient/token
# 4. Convert resulting vector to a list using `A.tolist()[0]`
# 5. `argsort` the importance scores to get sequence of ingredient indices ordered from most to least important
# 6. Find the most important ingredient that isn't on the ingredient list

# %%
# TODO: Get 16 most similar recipes

# TODO: Encode the 16 recipes

# TODO: Sum the recipe vectors by column to get ingredient importance scores

# TODO: Convert sparse vector to regular list with A.tolist()[0]

# TODO: argsort the importance scores

# TODO: Find most important ingredient not yet on the list of ingredients

# %% [markdown]
# ### 5. Add ingredient to recipe
#
# This is simply adding a word to `recipe_seed_str`

# %%
# TODO: add the first important ingredient to list of ingredients

# %% [markdown]
# ### 6. Repeat (Optional)
#
# Now we can repeat this process until we get an empty list of important ingredients:
# 1. Encode current recipe
# 2. Find similar recipes
# 3. Find important ingredients
# 4. Add important ingredient
#
# Might be helpful to define a couple of functions, like `find_similar_recipes()` and `find_important_ingredients()`...
#
# Only do this step if you're really curious about experimenting with generating unconventional ingredient lists. It's not going to be graded.

# %%
# TODO: Create find_similar_recipes(ingredients, recipes, vectorizer)

# TODO: Create find_important_ingredients(recipes)

# TODO: Create recipe by repeating calls to find_similar_recipes() and find_important_ingredients()
